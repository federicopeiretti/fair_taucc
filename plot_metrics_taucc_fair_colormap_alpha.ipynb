# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
root = os.getcwd()
root
# Out:
# './fair_taucc'

# %%
dataset = "movielens-1m"
sensitive = "age"
alpha = 0.9

# %%
df = pd.read_csv(root + f"/results/{dataset}/{sensitive}/taucc_fair/init_random/aggregated.csv")
df
# Out:
#       fair_major  fair_minor1  fair_minor2  tau_x_mean  tau_y_mean  \
# 0            0.0          0.0          0.0    0.116258    0.114772
# 1            0.0          0.0          0.1    0.118688    0.117632
# 2            0.0          0.0          0.2    0.116377    0.114817
# 3            0.0          0.0          0.3    0.118447    0.117343
# 4            0.0          0.0          0.4    0.119874    0.119874
# ...          ...          ...          ...         ...         ...
# 1326         1.0          1.0          0.6    0.054215    0.084525
# 1327         1.0          1.0          0.7    0.072381    0.083826
# 1328         1.0          1.0          0.8    0.045100    0.074539
# 1329         1.0          1.0          0.9    0.044814    0.073546
# 1330         1.0          1.0          1.0    0.016300    0.069938
#
#       NMI_true_labels_mean  AMI_true_labels_mean  ARI_true_labels_mean  \
# 0                 0.120918              0.118960              0.103526
# ...

# %%
mask_col1 = df['fair_major'].isin([0.9, 1.0])
mask_col2 = df['fair_minor1'].isin([0.9, 1.0])
mask_col3 = df['fair_minor2'].isin([0.9, 1.0])
zz = df[mask_col1 & mask_col2 & mask_col3]
zz[["fair_major","fair_minor1","fair_minor2","tau_x_mean","tau_y_mean","balance_bera_mean"]]
# Out:
#       fair_major  fair_minor1  fair_minor2  tau_x_mean  tau_y_mean  \
# 1197         0.9          0.9          0.9    0.068078    0.108316
# 1198         0.9          0.9          1.0    0.063318    0.095750
# 1208         0.9          1.0          0.9    0.047966    0.100223
# 1209         0.9          1.0          1.0    0.023729    0.079110
# 1318         1.0          0.9          0.9    0.024066    0.086335
# 1319         1.0          0.9          1.0    0.031047    0.075633
# 1329         1.0          1.0          0.9    0.044814    0.073546
# 1330         1.0          1.0          1.0    0.016300    0.069938
#
#       balance_bera_mean
# 1197           0.787095
# 1198           0.805606
# 1208           0.770045
# 1209           0.702092
# 1318           0.711787
# 1319           0.753390
# 1329           0.793489
# 1330           0.954411

# %%
df_vanilla = pd.read_csv(root + f"/results/{dataset}/{sensitive}/taucc_vanilla/init_random/results_aggregated.csv")
df_vanilla

# %%
values = np.unique(df["fair_minor1"])
values

# %%
plot_path = root + f"/plots/paper"

# %% [markdown]
# ## Plot of Fairness: Heatmap for Fairness

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

A, B = np.meshgrid(values, values)

temp = df[df["fair_major"] == alpha]
temp = temp.sort_values(by=["fair_minor1", "fair_minor2"], ascending=[False, True])
    
bera_pivot = temp.pivot_table(index='fair_minor1', columns='fair_minor2', values='balance_bera_mean', sort=False)
bera = bera_pivot.to_numpy()

im1 = plt.imshow(bera, cmap="viridis", vmin=0.0, vmax=1.0, extent=[values.min(), values.max(), values.min(), values.max()])
plt.xlim(0.0,1.0)
plt.ylim(0.0,1.0)
title = "Balance (Bera et al.) \n\n"
title += f"$\\alpha$ majority group = {alpha}"
plt.title(title)
plt.xlabel(r"$\alpha$ minority 2")
plt.ylabel(r"$\alpha$ minority 1")

#cbar_ax1 = fig.add_axes([0.05 + (i*3+1)*0.25, 0.9, 0.02, 0.05])
plt.colorbar(im1, orientation='vertical')
#plt.show()
plt.savefig(plot_path + f"/movielens_age_fairness.png", dpi=300, bbox_inches='tight')

#plt.suptitle("Balance (Bera et al.)", ha="center", va="top")

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

A, B = np.meshgrid(values, values)

temp = df[df["fair_major"] == alpha]
temp = temp.sort_values(by=["fair_minor1", "fair_minor2"], ascending=[False, True])
    
bera_pivot = temp.pivot_table(index='fair_minor1', columns='fair_minor2', values='KL_fairness_error_mean', sort=False)
bera = bera_pivot.to_numpy()

im1 = plt.imshow(bera, cmap="viridis", vmin=0.0, vmax=1.0, extent=[values.min(), values.max(), values.min(), values.max()])
plt.xlim(0.0,1.0)
plt.ylim(0.0,1.0)
title = "KL fairness error \n\n"
title += f"$\\alpha$ majority group = {alpha}"
plt.title(title)
plt.xlabel(r"$\alpha$ minority 2")
plt.ylabel(r"$\alpha$ minority 1")

#cbar_ax1 = fig.add_axes([0.05 + (i*3+1)*0.25, 0.9, 0.02, 0.05])
plt.colorbar(im1, orientation='vertical')
#plt.show()
plt.savefig(plot_path + f"/movielens_age_KL.png", dpi=300, bbox_inches='tight')

#plt.suptitle("Balance (Bera et al.)", ha="center", va="top")

# %% [markdown]
# ## NMI, AMI, ARI w.r.t. true labels

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

A, B = np.meshgrid(values, values)

temp = df[df["fair_major"] == alpha]
temp = temp.sort_values(by=["fair_minor1", "fair_minor2"], ascending=[False, True])
    
    
ch_pivot = temp.pivot_table(index='fair_minor1', columns='fair_minor2', values='ARI_true_labels_mean', sort=False)
ch = ch_pivot.to_numpy()

im = plt.imshow(ch, cmap="viridis", vmin=-1.0, vmax=1.0, extent=[values.min(), values.max(), values.min(), values.max()])
plt.xlim(0.0,1.0)
plt.ylim(0.0,1.0)
title = "ARI w.r.t true labels \n\n"
title += f"$\\alpha$ majority group = {alpha}"
plt.title(title)
plt.xlabel(r"$\alpha$ minority 2")
plt.ylabel(r"$\alpha$ minority 1")

plt.colorbar(im, orientation='vertical')
#plt.show()
plt.savefig(plot_path + f"/movielens_age_ARI_true.png", dpi=300, bbox_inches='tight')

#plt.savefig(plot_path + f"/quality_true_labels.png")

# %% [markdown]
# ## NMI, AMI, ARI w.r.t. rows

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

A, B = np.meshgrid(values, values)

temp = df[df["fair_major"] == alpha]
temp = temp.sort_values(by=["fair_minor1", "fair_minor2"], ascending=[False, True])

    
ch_pivot = temp.pivot_table(index='fair_minor1', columns='fair_minor2', values='ARI_rows_mean', sort=False)
ch = ch_pivot.to_numpy()

im = plt.imshow(ch, cmap="viridis", vmin=-1.0, vmax=1.0, extent=[values.min(), values.max(), values.min(), values.max()])
plt.xlim(0.0,1.0)
plt.ylim(0.0,1.0)
title = "ARI w.r.t Vanilla $\\tau$CC rows \n\n"
title += f"$\\alpha$ majority group = {alpha}"
plt.title(title)
plt.xlabel(r"$\alpha$ minority 2")
plt.ylabel(r"$\alpha$ minority 1")

plt.colorbar(im, orientation='vertical')
plt.savefig(plot_path + f"/movielens_age_ARI_rows.png", dpi=300, bbox_inches='tight')

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

A, B = np.meshgrid(values, values)

temp = df[df["fair_major"] == alpha]
temp = temp.sort_values(by=["fair_minor1", "fair_minor2"], ascending=[False, True])

    
ch_pivot = temp.pivot_table(index='fair_minor1', columns='fair_minor2', values='ARI_cols_mean', sort=False)
ch = ch_pivot.to_numpy()

im = plt.imshow(ch, cmap="viridis", vmin=-1.0, vmax=1.0, extent=[values.min(), values.max(), values.min(), values.max()])
plt.xlim(0.0,1.0)
plt.ylim(0.0,1.0)
title = "ARI w.r.t Vanilla $\\tau$CC columns \n\n"
title += f"$\\alpha$ majority group = {alpha}"
plt.title(title)
plt.xlabel(r"$\alpha$ minority 2")
plt.ylabel(r"$\alpha$ minority 1")

plt.colorbar(im, orientation='vertical')
plt.savefig(plot_path + f"/movielens_age_ARI_cols.png", dpi=300, bbox_inches='tight')

#plt.show()

# %%
A, B = np.meshgrid(values, values)

temp = df[df["fair_major"] == alpha]
temp = temp.sort_values(by=["fair_minor1", "fair_minor2"], ascending=[False, True])

ch_pivot = temp.pivot_table(index='fair_minor1', columns='fair_minor2', values='tau_x_mean', sort=False)
ch = ch_pivot.to_numpy()

im = plt.imshow(ch, cmap="viridis", vmin=0.0, vmax=1.0, extent=[values.min(), values.max(), values.min(), values.max()])
plt.xlim(0.0,1.0)
plt.ylim(0.0,1.0)
title = "tau_x \n\n"
title += f"$\\alpha$ majority group = {alpha}"
plt.title(title)
plt.xlabel(r"$\alpha$ minority 2")
plt.ylabel(r"$\alpha$ minority 1")

plt.colorbar(im, orientation='vertical')
plt.savefig(plot_path + f"/movielens_age_taux.png", dpi=300, bbox_inches='tight')

# %%
A, B = np.meshgrid(values, values)

temp = df[df["fair_major"] == alpha]
temp = temp.sort_values(by=["fair_minor1", "fair_minor2"], ascending=[False, True])

ch_pivot = temp.pivot_table(index='fair_minor1', columns='fair_minor2', values='tau_y_mean', sort=False)
ch = ch_pivot.to_numpy()

im = plt.imshow(ch, cmap="viridis", vmin=0.0, vmax=1.0, extent=[values.min(), values.max(), values.min(), values.max()])
plt.xlim(0.0,1.0)
plt.ylim(0.0,1.0)
title = "tau_y \n\n"
title += f"$\\alpha$ majority group = {alpha}"
plt.title(title)
plt.xlabel(r"$\alpha$ minority 2")
plt.ylabel(r"$\alpha$ minority 1")

plt.colorbar(im, orientation='vertical')
plt.savefig(plot_path + f"/movielens_age_tauy.png", dpi=300, bbox_inches='tight')
